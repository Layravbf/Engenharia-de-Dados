# %% [markdown]
# <a href="https://colab.research.google.com/github/Layravbf/Engenharia-de-Dados/blob/main/imoveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://www.vivareal.com.br/venda/parana/curitiba/apartamento_residencial/?pagina={}'

# %%
i = 1
ret = requests.get(url.format(i))
soup = bs(ret.text)
houses = soup.find_all('a', {'class': 'property-card__content-link js-card-title'})
qtd_imoveis = float(soup.find('strong', {'class': 'results-summary__count'}).text.replace('.', ''))

# %%
qtd_imoveis
# Out:
# 40179.0

# %%
df = pd.DataFrame(columns=['descricao', 'endereco', 'area', 'quartos', 'banheiros', 'vagas', 'valor', 'condominio', 'wlink'])

# %%
i = 0
while qtd_imoveis > df.shape[0]:
  i += 1
  print(f'valor i: {i} \t\t qtd_imoveis: {df.shape[0]}')
  ret = requests.get(url.format(i))
  soup = bs(ret.text)
  houses = soup.find_all('a', {'class': 'property-card__content-link js-card-title'})
  for house in houses: 
    try: 
      descricao = house.find('span', {'class': 'property-card__title'}).text.strip()
    except:
      descricao = None
    try: 
      endereco = house.find('span', {'class': 'property-card__address'}).text.strip()
    except:
      endereco = None
    try: 
      area = house.find('span', {'class': 'property-card__detail-area'}).text.strip()
    except:
      area = None
    try: 
      quartos = house.find('li', {'class': 'property-card__detail-room'}).span.text.strip()
    except:
      quartos = None
    try: 
      banheiros = house.find('li', {'class': 'property-card__detail-bathroom'}).span.text.strip()
    except:
      banheiros = None
    try: 
      vagas = house.find('li', {'class': 'property-card__detail-garage'}).span.text.strip() 
    except:
      vagas = None
    try: 
      valor = house.find('div', {'class': 'property-card__price'}).p.text.strip() 
    except:
      valor = None
    try: 
      condominio = house.find('strong', {'class': 'js-condo-price'}).text.strip() 
    except:
      condominio = None
    try: 
      wlink = 'https://www.vivareal.com.br/'+house['href']
    except:
      wlink = None

    df.loc[df.shape[0]] = [
        descricao,
        endereco,
        area,
        quartos,
        banheiros,
        vagas,
        valor,
        condominio,
        wlink
    ]
# Out:
# valor i: 1 		 qtd_imoveis: 432
# valor i: 2 		 qtd_imoveis: 468
# valor i: 3 		 qtd_imoveis: 504
# valor i: 4 		 qtd_imoveis: 540
# valor i: 5 		 qtd_imoveis: 576
# valor i: 6 		 qtd_imoveis: 612
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9fce403d13c0> in <module>
#      53         valor,
#      54         condominio,
# ---> 55         wlink
#      56     ]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2029                 value = Series(value, index=self.obj.columns, name=indexer)
#    2030
# -> 2031             self.obj._mgr = self.obj.append(value)._mgr
#    2032             self.obj._maybe_update_cacher(clear=True)
#    2033
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8967                 ignore_index=ignore_index,
#    8968                 verify_integrity=verify_integrity,
# -> 8969                 sort=sort,
#    8970             )
#    8971         ).__finalize__(self, method="append")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     531
#     532             new_data = concatenate_managers(
# --> 533                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     534             )
#     535             if not self.copy:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     214                 #  we can use np.concatenate, which is more performant
#     215                 #  than concat_compat
# --> 216                 values = np.concatenate(vals, axis=blk.ndim - 1)
#     217             else:
#     218                 # TODO(EA2D): special-casing not needed with 2D EAs
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                                    descricao  \
# 0    Apartamento com 3 Quartos à Venda, 88m²
# 1                                        MUV
# 2    Apartamento com 3 Quartos à Venda, 77m²
# 3    Apartamento com 2 Quartos à Venda, 58m²
# 4    Apartamento com 2 Quartos à Venda, 44m²
# 5   Apartamento com 3 Quartos à Venda, 180m²
# 6      Apartamento com  Quarto à Venda, 33m²
# 7      Apartamento com  Quarto à Venda, 33m²
# 8                              Easy District
# 9   Apartamento com 4 Quartos à Venda, 110m²
# 10   Apartamento com 3 Quartos à Venda, 93m²
# 11  Apartamento com 3 Quartos à Venda, 107m²
# 12   Apartamento com 2 Quartos à Venda, 82m²
# 13   Apartamento com 3 Quartos à Venda, 76m²
# 14  Apartamento com 3 Quartos à Venda, 113m²
# 15                               Mont Tannat
# 16   Apartamento com 3 Quartos à Venda, 53m²
# 17  Apartamento com 4 Quartos à Venda, 220m²
# 18   Apartamento com 3 Quartos à Venda, 49m²
# 19  Apartamento com 3 Quartos à Venda, 126m²
# 20   Apartamento com 2 Quartos à Venda, 70m²
# 21  Apartamento com 3 Quartos à Venda, 137m²
# 22     Apartamento com  Quarto à Venda, 20m²
# 23  Apartamento com 2 Quartos à Venda, 212m²
# 24   Apartamento com 3 Quartos à Venda, 79m²
# 25     Apartamento com  Quarto à Venda, 55m²
# 26   Apartamento com 3 Quartos à Venda, 59m²
# 27  Apartamento com 4 Quartos à Venda, 216m²
# 28   Apartamento com 2 Quartos à Venda, 50m²
# 29   Apartamento com 2 Quartos à Venda, 62m²
# 30   Apartamento com 3 Quartos à Venda, 67m²
# 31   Apartamento com 3 Quartos à Venda, 94m²
# 32   Apartamento com 3 Quartos à Venda, 87m²
# 33   Apartamento com 2 Quartos à Venda, 69m²
# 34   Apartamento com 3 Quartos à Venda, 58m²
# 35   Apartamento com 2 Quartos à Venda, 78m²
#
#                                              endereco   area quartos  \
# 0     Avenida Paraná, 1758 - Bacacheri, Curitiba - PR     88       3
# 1   Avenida Visconde de Guarapuava, 3070 - Centro,...  20-36       1
# 2   Rua Nossa Senhora de Nazaré, 615 - Boa Vista, ...     77       3
# 3   Avenida Visconde de Guarapuava, 3554 - Centro,...     58       2
# 4   Rua Juvenal Carvalho, 190 - Fazendinha, Curiti...     44       2
# 5   Rua Deputado Heitor Alencar Furtado, 2881 - Ec...    180       3
# 6   Rua Augusto de Mari, 3994 - Portão, Curitiba - PR     33       1
# 7    Rua Carlos Dietzsch, 475 - Portão, Curitiba - PR     33       1
# 8   Rua Desembargador Westphalen, 450 - Centro, Cu...  18-34     1-2
# 9       Rua Mauá, 838 - Alto da Glória, Curitiba - PR    110       4
# 10  Rua Jeremias Maciel Perretto, 646 - Campo Comp...     93       3
# 11  Rua Marechal Deodoro, 228 - Centro, Curitiba - PR    107       3
# 12    Rua Leão Sallum, 526 - Boa Vista, Curitiba - PR     82       2
# 13  Rua João Batista Dallarmi, 221 - Santo Inácio,...     76       3
# 14  Rua Capitão Souza Franco, 870 - Batel, Curitib...    113       3
# 15  Avenida Visconde de Guarapuava, 3116 - Centro,...  32-72     1-2
# 16  Rua Alfredo José Pinto, 1640 - Fazendinha, Cur...     53       3
# 17        Avenida Iguaçu, 2663 - Batel, Curitiba - PR    220       4
# 18      Rua Miguel Abrão, 610 - Portão, Curitiba - PR     49       3
# 19  Rua Professora Doracy Cezzarino, 138 - Portão,...    126       3
# 20  Rua Rodolfo Bernardelli, 438 - Uberaba, Curiti...     70       2
# 21  Avenida Anita Garibaldi, 1576 - Cabral, Curiti...    137       3
# 22  Rua Martim Afonso, 1543 - Bigorrilho, Curitiba...     20       1
# 23  Rua Padre Agostinho, 2545 - Bigorrilho, Curiti...    212       2
# 24  Rua Governador Agamenon Magalhães, 55 - Cristo...     79       3
# 25  Rua Amintas de Barros, 240 - Centro, Curitiba ...     55       1
# 26  Rua Rezala Simão, 650 - Santa Quitéria, Curiti...     59       3
# 27    Rua Lamenha Lins, 601 - Rebouças, Curitiba - PR    216       4
# 28  Rua Vale dos Pássaros, 93 - Cidade Industrial,...     50       2
# 29  Rua Jovino do Rosário, 1620 - Boa Vista, Curit...     62       2
# 30  Rua Mário Chalbaud Biscaia, 782 - Novo Mundo, ...     67       3
# 31  Rua Monsenhor Manoel Vicente, 316 - Água Verde...     94       3
# 32  Avenida Nossa Senhora da Luz, 160 - Bacacheri,...     87       3
# 33  Avenida Visconde de Guarapuava, 2764 - Centro,...     69       2
# 34  Estrada Guilherme Weigert, 2245 - Santa Cândid...     58       3
# 35   Rua Guaianazes, 882 - Vila Izabel, Curitiba - PR     78       2
#
#    banheiros vagas                                 valor condominio  \
# 0          2     1                            R$ 495.000     R$ 800
# 1          1    --              A partir de   R$ 187.000       None
# 2          2     1                            R$ 595.000     R$ 400
# 3          2     1                            R$ 595.000       None
# 4          1     1                            R$ 185.500     R$ 395
# 5          5     3                          R$ 1.680.000   R$ 1.300
# 6          1    --                            R$ 249.900     R$ 350
# 7          1     1                            R$ 225.000     R$ 350
# 8          1    --              A partir de   R$ 195.000       None
# 9          3     1                            R$ 570.000     R$ 750
# 10         2     2                            R$ 610.000     R$ 600
# 11         2    --                            R$ 300.000     R$ 700
# 12         2     2                            R$ 999.999     R$ 500
# 13         2     2                            R$ 679.900     R$ 490
# 14         2     1                            R$ 560.000     R$ 886
# 15       1-2   1-3                            R$ 279.900       None
# 16         1     1                            R$ 180.000     R$ 392
# 17         5     3                          R$ 3.899.000   R$ 2.800
# 18         1     1                            R$ 249.000     R$ 400
# 19         5     2                          R$ 1.350.000     R$ 800
# 20         2     1                            R$ 368.000     R$ 290
# 21         3     2                            R$ 690.000     R$ 525
# 22         1    --                            R$ 239.900     R$ 350
# 23         4     4                          R$ 4.100.000   R$ 3.500
# 24         2     1                            R$ 330.000     R$ 600
# 25         1     1                            R$ 480.000     R$ 600
# 26         1     1                            R$ 230.000     R$ 300
# 27         4     1  R$ 680.000   Preço abaixo do mercado       None
# 28         1     1                            R$ 130.000     R$ 352
# 29         2     1  R$ 465.000   Preço abaixo do mercado     R$ 400
# 30         2     1                            R$ 340.000     R$ 320
# 31         2     2                            R$ 680.000     R$ 530
# 32         2     1  R$ 560.000   Preço abaixo do mercado     R$ 517
# 33         2     1                            R$ 590.000     R$ 650
# 34         1     1                            R$ 225.000     R$ 260
# 35         2     2                            R$ 580.000     R$ 400
#
#                                                 wlink
# 0   https://www.vivareal.com.br//imovel/apartament...
# 1   https://www.vivareal.com.br//imoveis-lancament...
# 2   https://www.vivareal.com.br//imovel/apartament...
# 3   https://www.vivareal.com.br//imovel/apartament...
# 4   https://www.vivareal.com.br//imovel/apartament...
# 5   https://www.vivareal.com.br//imovel/apartament...
# 6   https://www.vivareal.com.br//imovel/apartament...
# 7   https://www.vivareal.com.br//imovel/apartament...
# 8   https://www.vivareal.com.br//imoveis-lancament...
# 9   https://www.vivareal.com.br//imovel/apartament...
# 10  https://www.vivareal.com.br//imovel/apartament...
# 11  https://www.vivareal.com.br//imovel/apartament...
# 12  https://www.vivareal.com.br//imovel/apartament...
# 13  https://www.vivareal.com.br//imovel/apartament...
# 14  https://www.vivareal.com.br//imovel/apartament...
# 15  https://www.vivareal.com.br//imoveis-lancament...
# 16  https://www.vivareal.com.br//imovel/apartament...
# 17  https://www.vivareal.com.br//imovel/apartament...
# 18  https://www.vivareal.com.br//imovel/apartament...
# 19  https://www.vivareal.com.br//imovel/apartament...
# 20  https://www.vivareal.com.br//imovel/apartament...
# 21  https://www.vivareal.com.br//imovel/apartament...
# 22  https://www.vivareal.com.br//imovel/apartament...
# 23  https://www.vivareal.com.br//imovel/apartament...
# 24  https://www.vivareal.com.br//imovel/apartament...
# 25  https://www.vivareal.com.br//imovel/apartament...
# 26  https://www.vivareal.com.br//imovel/apartament...
# 27  https://www.vivareal.com.br//imovel/apartament...
# 28  https://www.vivareal.com.br//imovel/apartament...
# 29  https://www.vivareal.com.br//imovel/apartament...
# 30  https://www.vivareal.com.br//imovel/apartament...
# 31  https://www.vivareal.com.br//imovel/apartament...
# 32  https://www.vivareal.com.br//imovel/apartament...
# 33  https://www.vivareal.com.br//imovel/apartament...
# 34  https://www.vivareal.com.br//imovel/apartament...
# 35  https://www.vivareal.com.br//imovel/apartament...

# %%
df.to_csv('banco_de_imoveis.csv', sep=';', index=False)
